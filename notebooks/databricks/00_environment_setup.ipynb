# %%
# %sql

-- Create the Unity Catalog catalog used by the project

CREATE CATALOG IF NOT EXISTS online_retail_aws;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql

-- Confirm that the project catalog exists

SHOW CATALOGS;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>dbacademy</td></tr><tr><td>online_retail</td></tr><tr><td>online_retail_aws</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr><tr><td>workspace</td></tr></tbody></table></div>

# %%
# %sql

-- Create schemas for pipeline layers and operational metadata

CREATE SCHEMA IF NOT EXISTS online_retail_aws.bronze;

CREATE SCHEMA IF NOT EXISTS online_retail_aws.silver;

CREATE SCHEMA IF NOT EXISTS online_retail_aws.gold;

CREATE SCHEMA IF NOT EXISTS online_retail_aws.control;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql

-- Confirm that the Medallion and control schemas exist

SHOW SCHEMAS IN online_retail_aws;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>databaseName</th></tr></thead><tbody><tr><td>bronze</td></tr><tr><td>control</td></tr><tr><td>default</td></tr><tr><td>gold</td></tr><tr><td>information_schema</td></tr><tr><td>silver</td></tr></tbody></table></div>

# %%
# %sql
-- Create the Delta table used for pipeline auditing and monitoring

CREATE TABLE IF NOT EXISTS online_retail_aws.control.pipeline_runs
(
    run_id STRING,
    batch_id STRING,
    layer_name STRING,
    status STRING,
    start_timestamp TIMESTAMP,
    end_timestamp TIMESTAMP,
    input_row_count BIGINT,
    output_row_count BIGINT,
    error_message STRING
)
USING DELTA
LOCATION 's3://online-retail-databricks/tables/control/pipeline_runs/';

# %%
# %sql

-- Confirm that the control table exists

SHOW TABLES IN online_retail_aws.control;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>control</td><td>pipeline_runs</td><td>false</td></tr></tbody></table></div>

# %%
# %sql

-- Inspect the control table column definitions

DESCRIBE TABLE online_retail_aws.control.pipeline_runs;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
